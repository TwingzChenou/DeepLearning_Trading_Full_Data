# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

# %%
list_tickers = ["BTC-USD", "ETH-USD", "XRP-USD", "USDT-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# %%
data_Crypto = pd.DataFrame()

# Télécharger les données pour chaque ticker
for ticker in list_tickers:

    print(f"Téléchargement des données pour {ticker}")

    # Télécharger les données de l'action entre les dates spécifiées
    data = yf.download(
                        ticker,
                        interval="1d",
                        period="max",
                        auto_adjust=True,
                        actions=False
                        )

    # Ajouter une colonne pour identifier le ticker
    data['Ticker'] = ticker

    # On retire le niveau des tickers pour ne garder que 'Close' et 'Volume'
    data.columns = data.columns.droplevel(level=1)

    # Concaténer les données dans la DataFrame globale
    data_Crypto= pd.concat([data_Crypto, data])

# Affichage de la DataFrame résultante
data_Crypto
# Out:
# Téléchargement des données pour BTC-USD
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour ETH-USD
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour XRP-USD
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour USDT-USD
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour BNB-USD
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour SOL-USD
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour DOGE-USD
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open      Volume  \
# Date
# 2014-09-17  457.334015  468.174011  452.421997  465.864014    21056800
# 2014-09-18  424.440002  456.859985  413.104004  456.859985    34483200
# 2014-09-19  394.795990  427.834991  384.532013  424.102997    37919700
# 2014-09-20  408.903992  423.295990  389.882996  394.673004    36863600
# 2014-09-21  398.821014  412.425995  393.181000  408.084991    26580100
# ...                ...         ...         ...         ...         ...
# 2025-09-27    0.230836    0.234215    0.228247    0.232629  1404236029
# 2025-09-28    0.237388    0.237472    0.225417    0.230838  1629383714
# 2025-09-29    0.235057    0.238685    0.229170    0.237389  2451434578
# 2025-09-30    0.232905    0.235651    0.226797    0.235067  2112968133
# 2025-10-01    0.244280    0.244384    0.230945    0.232904  2694552064
#
# Price         Ticker
# Date
# 2014-09-17   BTC-USD
# 2014-09-18   BTC-USD
# 2014-09-19   BTC-USD
# 2014-09-20   BTC-USD
# 2014-09-21   BTC-USD
# ...              ...
# 2025-09-27  DOGE-USD
# 2025-09-28  DOGE-USD
# 2025-09-29  DOGE-USD
# 2025-09-30  DOGE-USD
# 2025-10-01  DOGE-USD
#
# [20454 rows x 6 columns]

# %%
a = data_Crypto.sort_values(by='Date', ascending=True)
a
# Out:
# Price             Close         High          Low         Open        Volume  \
# Date
# 2014-09-17   457.334015   468.174011   452.421997   465.864014      21056800
# 2014-09-18   424.440002   456.859985   413.104004   456.859985      34483200
# 2014-09-19   394.795990   427.834991   384.532013   424.102997      37919700
# 2014-09-20   408.903992   423.295990   389.882996   394.673004      36863600
# 2014-09-21   398.821014   412.425995   393.181000   408.084991      26580100
# ...                 ...          ...          ...          ...           ...
# 2025-10-01   219.518723   219.518723   206.640182   208.736389    8492360192
# 2025-10-01     2.944130     2.950404     2.816904     2.846860    6520500224
# 2025-10-01     1.000337     1.000495     0.999815     1.000094  152335728640
# 2025-10-01  1023.699463  1034.669922  1004.037781  1008.450256    3166963200
# 2025-10-01     0.244280     0.244384     0.230945     0.232904    2694552064
#
# Price         Ticker
# Date
# 2014-09-17   BTC-USD
# 2014-09-18   BTC-USD
# 2014-09-19   BTC-USD
# 2014-09-20   BTC-USD
# 2014-09-21   BTC-USD
# ...              ...
# 2025-10-01   SOL-USD
# 2025-10-01   XRP-USD
# 2025-10-01  USDT-USD
# 2025-10-01   BNB-USD
# 2025-10-01  DOGE-USD
#
# [20454 rows x 6 columns]

# %%
data_Crypto = data_Crypto.reset_index()
data_Crypto
# Out:
# Price       Date       Close        High         Low        Open      Volume  \
# 0     2014-09-17  457.334015  468.174011  452.421997  465.864014    21056800
# 1     2014-09-18  424.440002  456.859985  413.104004  456.859985    34483200
# 2     2014-09-19  394.795990  427.834991  384.532013  424.102997    37919700
# 3     2014-09-20  408.903992  423.295990  389.882996  394.673004    36863600
# 4     2014-09-21  398.821014  412.425995  393.181000  408.084991    26580100
# ...          ...         ...         ...         ...         ...         ...
# 20449 2025-09-27    0.230836    0.234215    0.228247    0.232629  1404236029
# 20450 2025-09-28    0.237388    0.237472    0.225417    0.230838  1629383714
# 20451 2025-09-29    0.235057    0.238685    0.229170    0.237389  2451434578
# 20452 2025-09-30    0.232905    0.235651    0.226797    0.235067  2112968133
# 20453 2025-10-01    0.244280    0.244384    0.230945    0.232904  2694552064
#
# Price    Ticker
# 0       BTC-USD
# 1       BTC-USD
# 2       BTC-USD
# 3       BTC-USD
# 4       BTC-USD
# ...         ...
# 20449  DOGE-USD
# 20450  DOGE-USD
# 20451  DOGE-USD
# 20452  DOGE-USD
# 20453  DOGE-USD
#
# [20454 rows x 7 columns]

# %%
data_Crypto.to_parquet('/Users/forget/Library/Mobile Documents/com~apple~CloudDocs/Project Stock Market Deep Learning/Data/data_Crypto.parquet')

# %%
data_Crypto.sort_values('Date', ascending=True, inplace=True)
data_Crypto
# Out:
# Price       Date        Close         High          Low         Open  \
# 0     2014-09-17   457.334015   468.174011   452.421997   465.864014
# 1     2014-09-18   424.440002   456.859985   413.104004   456.859985
# 2     2014-09-19   394.795990   427.834991   384.532013   424.102997
# 3     2014-09-20   408.903992   423.295990   389.882996   394.673004
# 4     2014-09-21   398.821014   412.425995   393.181000   408.084991
# ...          ...          ...          ...          ...          ...
# 17569 2025-10-01   219.518723   219.518723   206.640182   208.736389
# 9800  2025-10-01     2.944130     2.950404     2.816904     2.846860
# 12684 2025-10-01     1.000337     1.000495     0.999815     1.000094
# 15568 2025-10-01  1023.699463  1034.669922  1004.037781  1008.450256
# 20453 2025-10-01     0.244280     0.244384     0.230945     0.232904
#
# Price        Volume    Ticker
# 0          21056800   BTC-USD
# 1          34483200   BTC-USD
# 2          37919700   BTC-USD
# 3          36863600   BTC-USD
# 4          26580100   BTC-USD
# ...             ...       ...
# 17569    8492360192   SOL-USD
# 9800     6520500224   XRP-USD
# 12684  152335728640  USDT-USD
# 15568    3166963200   BNB-USD
# 20453    2694552064  DOGE-USD
#
# [20454 rows x 7 columns]
