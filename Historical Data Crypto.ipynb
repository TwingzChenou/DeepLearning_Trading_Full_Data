# %%
import pandas as pd
import yfinance as yf
from datetime import datetime, timedelta

# %%
list_tickers = ["BTC-USD", "ETH-USD", "XRP-USD", "USDT-USD", "BNB-USD", "SOL-USD", "DOGE-USD"]

# %%
data_Crypto = pd.DataFrame()

# Télécharger les données pour chaque ticker
for ticker in list_tickers:

    print(f"Téléchargement des données pour {ticker}")

    # Télécharger les données de l'action entre les dates spécifiées
    data = yf.download(
                        ticker,
                        interval="1d",
                        period="max",
                        auto_adjust=True,
                        actions=False
                        )

    # Ajouter une colonne pour identifier le ticker
    data['Ticker'] = ticker

    # On retire le niveau des tickers pour ne garder que 'Close' et 'Volume'
    data.columns = data.columns.droplevel(level=1)

    # Concaténer les données dans la DataFrame globale
    data_Crypto= pd.concat([data_Crypto, data])

# Affichage de la DataFrame résultante
data_Crypto
# Out:
# Téléchargement des données pour BTC-USD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour ETH-USD
# Téléchargement des données pour XRP-USD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour USDT-USD
# Téléchargement des données pour BNB-USD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Téléchargement des données pour SOL-USD
# Téléchargement des données pour DOGE-USD
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open      Volume  \
# Date
# 2014-09-17  457.334015  468.174011  452.421997  465.864014    21056800
# 2014-09-18  424.440002  456.859985  413.104004  456.859985    34483200
# 2014-09-19  394.795990  427.834991  384.532013  424.102997    37919700
# 2014-09-20  408.903992  423.295990  389.882996  394.673004    36863600
# 2014-09-21  398.821014  412.425995  393.181000  408.084991    26580100
# ...                ...         ...         ...         ...         ...
# 2025-10-03    0.258603    0.264969    0.253547    0.261940  3285893533
# 2025-10-04    0.250917    0.259405    0.247337    0.258604  2121406683
# 2025-10-05    0.252954    0.264665    0.249815    0.250915  3422890843
# 2025-10-06    0.266313    0.270047    0.251322    0.252954  3938750191
# 2025-10-07    0.261098    0.267863    0.258087    0.266294  4154484224
#
# Price         Ticker
# Date
# 2014-09-17   BTC-USD
# 2014-09-18   BTC-USD
# 2014-09-19   BTC-USD
# 2014-09-20   BTC-USD
# 2014-09-21   BTC-USD
# ...              ...
# 2025-10-03  DOGE-USD
# 2025-10-04  DOGE-USD
# 2025-10-05  DOGE-USD
# 2025-10-06  DOGE-USD
# 2025-10-07  DOGE-USD
#
# [20496 rows x 6 columns]

# %%
a = data_Crypto.sort_values(by='Date', ascending=True)
a
# Out:
# Price             Close         High          Low         Open        Volume  \
# Date
# 2014-09-17   457.334015   468.174011   452.421997   465.864014      21056800
# 2014-09-18   424.440002   456.859985   413.104004   456.859985      34483200
# 2014-09-19   394.795990   427.834991   384.532013   424.102997      37919700
# 2014-09-20   408.903992   423.295990   389.882996   394.673004      36863600
# 2014-09-21   398.821014   412.425995   393.181000   408.084991      26580100
# ...                 ...          ...          ...          ...           ...
# 2025-10-07   230.427109   235.040070   228.819824   232.512863    7729071616
# 2025-10-07     2.973836     2.998861     2.960505     2.990715    6479801344
# 2025-10-07     1.000545     1.000695     1.000101     1.000176  168044363776
# 2025-10-07  1298.236938  1298.605469  1209.572266  1223.624146    6926119424
# 2025-10-07     0.261098     0.267863     0.258087     0.266294    4154484224
#
# Price         Ticker
# Date
# 2014-09-17   BTC-USD
# 2014-09-18   BTC-USD
# 2014-09-19   BTC-USD
# 2014-09-20   BTC-USD
# 2014-09-21   BTC-USD
# ...              ...
# 2025-10-07   SOL-USD
# 2025-10-07   XRP-USD
# 2025-10-07  USDT-USD
# 2025-10-07   BNB-USD
# 2025-10-07  DOGE-USD
#
# [20496 rows x 6 columns]

# %%
data_Crypto = data_Crypto.reset_index()
data_Crypto
# Out:
# Price       Date       Close        High         Low        Open      Volume  \
# 0     2014-09-17  457.334015  468.174011  452.421997  465.864014    21056800
# 1     2014-09-18  424.440002  456.859985  413.104004  456.859985    34483200
# 2     2014-09-19  394.795990  427.834991  384.532013  424.102997    37919700
# 3     2014-09-20  408.903992  423.295990  389.882996  394.673004    36863600
# 4     2014-09-21  398.821014  412.425995  393.181000  408.084991    26580100
# ...          ...         ...         ...         ...         ...         ...
# 20491 2025-10-03    0.258603    0.264969    0.253547    0.261940  3285893533
# 20492 2025-10-04    0.250917    0.259405    0.247337    0.258604  2121406683
# 20493 2025-10-05    0.252954    0.264665    0.249815    0.250915  3422890843
# 20494 2025-10-06    0.266313    0.270047    0.251322    0.252954  3938750191
# 20495 2025-10-07    0.261098    0.267863    0.258087    0.266294  4154484224
#
# Price    Ticker
# 0       BTC-USD
# 1       BTC-USD
# 2       BTC-USD
# 3       BTC-USD
# 4       BTC-USD
# ...         ...
# 20491  DOGE-USD
# 20492  DOGE-USD
# 20493  DOGE-USD
# 20494  DOGE-USD
# 20495  DOGE-USD
#
# [20496 rows x 7 columns]

# %%
data_Crypto.to_parquet('/Users/forget/Library/Mobile Documents/com~apple~CloudDocs/Project Stock Market Deep Learning/Data/data_Crypto.parquet')

# %%
data_Crypto.sort_values('Date', ascending=True, inplace=True)
data_Crypto
# Out:
# Price       Date        Close         High          Low         Open  \
# 0     2014-09-17   457.334015   468.174011   452.421997   465.864014
# 1     2014-09-18   424.440002   456.859985   413.104004   456.859985
# 2     2014-09-19   394.795990   427.834991   384.532013   424.102997
# 3     2014-09-20   408.903992   423.295990   389.882996   394.673004
# 4     2014-09-21   398.821014   412.425995   393.181000   408.084991
# ...          ...          ...          ...          ...          ...
# 17605 2025-10-07   230.427109   235.040070   228.819824   232.512863
# 9818  2025-10-07     2.973836     2.998861     2.960505     2.990715
# 12708 2025-10-07     1.000545     1.000695     1.000101     1.000176
# 15598 2025-10-07  1298.236938  1298.605469  1209.572266  1223.624146
# 20495 2025-10-07     0.261098     0.267863     0.258087     0.266294
#
# Price        Volume    Ticker
# 0          21056800   BTC-USD
# 1          34483200   BTC-USD
# 2          37919700   BTC-USD
# 3          36863600   BTC-USD
# 4          26580100   BTC-USD
# ...             ...       ...
# 17605    7729071616   SOL-USD
# 9818     6479801344   XRP-USD
# 12708  168044363776  USDT-USD
# 15598    6926119424   BNB-USD
# 20495    4154484224  DOGE-USD
#
# [20496 rows x 7 columns]
